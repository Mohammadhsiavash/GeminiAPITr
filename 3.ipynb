# %%
from PIL import Image
img = Image.open('benji.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=793x412>

# %%
import google.generativeai as genai
import os
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override=True)
genai.configure(api_key=os.environ.get("GOOGLE_API_KEY"))
# listing available moddels
for m in genai.list_models():
    if "generateContent" in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/learnlm-1.5-pro-experimental
# models/gemini-exp-1114
# models/gemini-exp-1121

# %%
model = genai.GenerativeModel('learnlm-1.5-pro-experimental')
prompt = 'describ this image and write a story about it'
response = model.generate_content([prompt, img])
print(response.text)
# Out:
# The image shows a small, fluffy, reddish-brown puppy, likely a poodle mix, attempting to eat a chunk of cucumber held by a human hand. The puppy's fur is thick and curly, and its expression is one of focused determination as it tries to bite into the vegetable. The puppy is on a tiled floor, suggesting the scene is likely a kitchen or bathroom.  The human hand holding the cucumber is fair-skinned.
#
#
# **Story:**
#
# Barnaby the miniature poodle puppy was a whirlwind of fluffy chaos. He chased dust bunnies with the ferocity of a lion hunting a gazelle and barked at his own reflection with bewilderment. But most of all, Barnaby loved to eat. Everything was fair game: shoelaces, fallen leaves, the occasional rogue sock.
#
# Today's culinary adventure involved a peculiar green object his human, Lily, was offering him. It smelled… interesting. Earthy and fresh, unlike his usual kibble. Barnaby approached cautiously, his tiny nose twitching. Lily giggled, holding the cucumber chunk closer.
#
# Barnaby nibbled tentatively. The texture was surprising – cool and crisp, with a satisfying crunch. He chomped down harder, his little jaws working furiously.  It wasn't quite as delicious as the bacon Lily sometimes snuck him (don't tell!), but it was certainly intriguing.  He wrestled with the slippery cucumber, determined to conquer this new, oddly shaped treat.  Juice dribbled down his chin, and a tiny piece broke off, landing on the tile with a soft plop. Barnaby, undeterred, continued his valiant effort, his tail wagging with the excitement of discovery.  He might not understand what this green thing was, but he knew one thing for sure:  it was an adventure for his taste buds. And for Barnaby, that was all that mattered.
